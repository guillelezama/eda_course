# %% [markdown]
# # Turnout y votos a candidatos

# %% [markdown]
# La pregunta es:
# ¿Existe una relación entre el nivel de participación electoral (turnout) en los distritos electorales y la proporción de votos obtenidos por el candidato perdedor?
#
# La pregunta está inspirada en este artículo: https://ladiaria.com.uy/elecciones/articulo/2024/6/el-enigma-de-las-internas-la-distancia-entre-orsi-y-cosse/
#
# y podría ser un análisis que le sirva a distintos candidatos en el futuro: ¿Me conviene o no me conviene la alta participación?
#
# Analicemos el caso de Carolina Cosse y el Frente Amplio.

# %%
import pandas as pd

# %%
# 2. Leer la Data
archivo = 'ODN Total Pais Circuito Hoja_0.xlsx'
# `skiprows` se usa para saltar las filas iniciales
df = pd.read_excel(archivo, skiprows=8)

# %%
# @title
# 3.a Número de columnas
num_columnas = df.shape[1]
print(f'Número de columnas: {num_columnas}')
# Out:
# Número de columnas: 9

# %%
# @title
# 3.b Número de filas
num_filas = df.shape[0]
print(f'Número de filas: {num_filas}')
# Out:
# Número de filas: 237917

# %%
# @title
# 4. Ejecutar .info() y .head()
df.info()
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237917 entries, 0 to 237916
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ACTO          237917 non-null  datetime64[ns]
#  1   CONVOCATORIA  237917 non-null  object
#  2   DEPTO         237917 non-null  object
#  3   CIRCUITO      237917 non-null  int64
#  4   SERIES        237917 non-null  object
#  5   ESCRUTINIO    237917 non-null  object
#  6   PRECANDIDATO  237917 non-null  object
#  7   HOJA          237917 non-null  int64
#  8   CNT_VOTOS     237917 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 16.3+ MB
#         ACTO            CONVOCATORIA       DEPTO  CIRCUITO SERIES  \
# 0 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 1 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 2 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 3 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 4 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
#
#       ESCRUTINIO                 PRECANDIDATO  HOJA  CNT_VOTOS
# 0  Departamental  COSSE GARRIDO, Ana Carolina    90         13
# 1  Departamental  COSSE GARRIDO, Ana Carolina   567          1
# 2  Departamental  COSSE GARRIDO, Ana Carolina  1001          9
# 3  Departamental  COSSE GARRIDO, Ana Carolina  1358          6
# 4  Departamental  COSSE GARRIDO, Ana Carolina  1808          2

# %%
# @title
# 5. Ver la parte superior e inferior de los datos
print("Parte superior del dataset:")
print(df.head())
print("Parte inferior del dataset:")
print(df.tail())
# Out:
# Parte superior del dataset:
#         ACTO            CONVOCATORIA       DEPTO  CIRCUITO SERIES  \
# 0 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 1 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 2 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 3 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
# 4 2024-06-30  Frente_Amplio_-_O.D.N.  Montevideo         1    AAA
#
#       ESCRUTINIO                 PRECANDIDATO  HOJA  CNT_VOTOS
# 0  Departamental  COSSE GARRIDO, Ana Carolina    90         13
# 1  Departamental  COSSE GARRIDO, Ana Carolina   567          1
# 2  Departamental  COSSE GARRIDO, Ana Carolina  1001          9
# 3  Departamental  COSSE GARRIDO, Ana Carolina  1358          6
# 4  Departamental  COSSE GARRIDO, Ana Carolina  1808          2
# Parte inferior del dataset:
#              ACTO        CONVOCATORIA       DEPTO  CIRCUITO SERIES  \
# 237912 2024-06-30  Devolución__O.D.N.  Tacuarembó       160    TDC
# 237913 2024-06-30  Devolución__O.D.N.  Tacuarembó       179    TED
# 237914 2024-06-30  Devolución__O.D.N.  Tacuarembó      9000    TZZ
# 237915 2024-06-30  Devolución__O.D.N.  Tacuarembó      9001    TZZ
# 237916 2024-06-30  Devolución__O.D.N.  Tacuarembó      9002    TZZ
#
#            ESCRUTINIO                 PRECANDIDATO  HOJA  CNT_VOTOS
# 237912  Departamental  PAIVA FIURES, Pablo Marcelo  7005          1
# 237913  Departamental  PAIVA FIURES, Pablo Marcelo  7005          1
# 237914  Departamental  PAIVA FIURES, Pablo Marcelo  7005          1
# 237915  Departamental  PAIVA FIURES, Pablo Marcelo  7005          2
# 237916  Departamental  PAIVA FIURES, Pablo Marcelo  7005          4

# %%
# @title
# 6. Verificar los n's. En Uruguay hay unos 7000 circuitos.
#Contar cuántas veces aparece cada PRECANDIDATO en las observaciones únicas del par (SERIE, CIRCUITO)
# Agrupamos por PRECANDIDATO y contamos las observaciones únicas del par (SERIE, CIRCUITO)

# Creamos una nueva columna que combina SERIE y CIRCUITO para identificar las tuples únicas
df['SERIE_CIRCUITO'] = df[['SERIES', 'CIRCUITO']].apply(tuple, axis=1)

# Eliminamos duplicados para contar las tuples únicas por PRECANDIDATO
df_unicos = df.drop_duplicates(subset=['PRECANDIDATO', 'SERIE_CIRCUITO'])

# Contamos cuántas veces aparece cada PRECANDIDATO en las tuples únicas de SERIE y CIRCUITO
conteo_precandidato = df_unicos['PRECANDIDATO'].value_counts()
print("Número de veces que cada PRECANDIDATO aparece en observaciones únicas de (SERIE, CIRCUITO):")
print(conteo_precandidato)
# Out:
# Número de veces que cada PRECANDIDATO aparece en observaciones únicas de (SERIE, CIRCUITO):
# DELGADO CERETTA, Alvaro Luis           7167
# ORSI MARTINEZ, Yamandu Ramon           7104
# COSSE GARRIDO, Ana Carolina            7009
# RAFFO DEGEROMINI, Maria Laura          6990
# OJEDA SPITZ, Andres                    6742
# SILVA GARCIA, Robert                   5833
# MANINI STRATTA, Guido                  5517
# GANDINI ASTESIANO, Jorge Osvaldo       5297
# GURMENDEZ ARMAND UGON, Gabriel         4872
# VIERA DUARTE, Tabare                   3942
# SALLE LORIER, Gustavo Alberto          2947
# LIMA PROSERPIO, Andrés Pablo           2755
# MIERES GOMEZ, Pablo Andres             1857
# MARTÍNEZ MARUCA, Walter Gonzalo        1645
# ACHE BATLLE, Carolina                   930
# LUST HITTA, Eduardo Manuel              927
# RODRIGUEZ GONZALEZ, Rita Mercedes       886
# BONICA SIERRA, Jorge Enrique            870
# OTORMIN GOMEZ, Juan Carlos              790
# VEGA ERRAMUSPE, Cesar Enrique           705
# IAFIGLIOLA PIMENTEL, Carlos Alberto     650
# FRANCHI SORIA, Guillermo Anibal         538
# CORBRAN RIZZO, Roxana Lilián            413
# PETKOVICH MOLL, Nelson Ignacio          409
# PEREZ BANCHERO, Felipe Martin           368
# SCIUTO OLIVERA, Ruben Javier            329
# MARTINEZ IZAGUIRRE, Ruben Ariel         277
# VIÑAS ORTIZ, Raul Eduardo               262
# PAIVA FIURES, Pablo Marcelo             209
# GONZALEZ LEGNANI, Zaida Eloisa          154
# Name: PRECANDIDATO, dtype: int64

# %%
# @title
# 7. Validar con datos externos. Sabemos cuánto sacó cada partido, y cuánto sacó cada candidato.
# Sumar todos los valores de CNT_VOTOS por CONVOCATORIA
# Sumar todos los valores de CNT_VOTOS por PRECANDIDATO
# Calcular los shares de cada PRECANDIDATO dentro de cada CONVOCATORIA

# Suma de CNT_VOTOS por CONVOCATORIA
suma_votos_por_convocatoria = df.groupby('CONVOCATORIA')['CNT_VOTOS'].sum()
print("Suma de CNT_VOTOS por CONVOCATORIA:")
print(suma_votos_por_convocatoria)

# Suma de CNT_VOTOS por PRECANDIDATO dentro de cada CONVOCATORIA
suma_votos_por_precandidato_y_convocatoria = df.groupby(['CONVOCATORIA', 'PRECANDIDATO'])['CNT_VOTOS'].sum()

# Calcular las participaciones de cada PRECANDIDATO dentro de cada CONVOCATORIA
participacion_por_precandidato = suma_votos_por_precandidato_y_convocatoria / suma_votos_por_convocatoria


# Shares de cada pre candidato
print(participacion_por_precandidato)
# Out:
# Suma de CNT_VOTOS por CONVOCATORIA:
# CONVOCATORIA
# Asamblea_Popular_-_O.D.N.                2204
# Avanzar_Republicano_O.D.N.                577
# Basta_Ya_O.D.N.                          1053
# Cabildo_Abierto_O.D.N.                  17787
# Coalición_Republicana_O.D.N.             1053
# Colorado_-_O.D.N.                      102486
# Constitucional_Ambientalista_O.D.N.      1213
# Devolución__O.D.N.                        316
# Frente_Amplio_-_O.D.N.                 414739
# Identidad_Soberana_O.D.N.                4739
# Independiente_-_O.D.N.                   2847
# Libertario_O.D.N.                         492
# Nacional_-_O.D.N.                      330416
# P.E.R.I._-_O.D.N.                         876
# Partido_de_la_Armonía_O.D.N.              344
# Patria_Alternativa_O.D.N.                 384
# Por__Los_Cambios_Necesarios_O.D.N.        731
# Verde_Animalista_O.D.N.                  1402
# Name: CNT_VOTOS, dtype: int64
# CONVOCATORIA                         PRECANDIDATO
# Asamblea_Popular_-_O.D.N.            MARTÍNEZ MARUCA, Walter Gonzalo        1.000000
# Avanzar_Republicano_O.D.N.           PEREZ BANCHERO, Felipe Martin          1.000000
# Basta_Ya_O.D.N.                      BONICA SIERRA, Jorge Enrique           1.000000
# Cabildo_Abierto_O.D.N.               MANINI STRATTA, Guido                  1.000000
# Coalición_Republicana_O.D.N.         OTORMIN GOMEZ, Juan Carlos             1.000000
# Colorado_-_O.D.N.                    ACHE BATLLE, Carolina                  0.011484
#                                      GONZALEZ LEGNANI, Zaida Eloisa         0.001659
#                                      GURMENDEZ ARMAND UGON, Gabriel         0.185547
#                                      OJEDA SPITZ, Andres                    0.393781
#                                      SILVA GARCIA, Robert                   0.224860
#                                      VIERA DUARTE, Tabare                   0.182669
# Constitucional_Ambientalista_O.D.N.  LUST HITTA, Eduardo Manuel             1.000000
# Devolución__O.D.N.                   PAIVA FIURES, Pablo Marcelo            1.000000
# Frente_Amplio_-_O.D.N.               COSSE GARRIDO, Ana Carolina            0.375089
#                                      LIMA PROSERPIO, Andrés Pablo           0.031297
#                                      ORSI MARTINEZ, Yamandu Ramon           0.593614
# Identidad_Soberana_O.D.N.            SALLE LORIER, Gustavo Alberto          1.000000
# Independiente_-_O.D.N.               MIERES GOMEZ, Pablo Andres             1.000000
# Libertario_O.D.N.                    PETKOVICH MOLL, Nelson Ignacio         1.000000
# Nacional_-_O.D.N.                    CORBRAN RIZZO, Roxana Lilián           0.001752
#                                      DELGADO CERETTA, Alvaro Luis           0.744637
#                                      GANDINI ASTESIANO, Jorge Osvaldo       0.058208
#                                      IAFIGLIOLA PIMENTEL, Carlos Alberto    0.002582
#                                      RAFFO DEGEROMINI, Maria Laura          0.192821
# P.E.R.I._-_O.D.N.                    VEGA ERRAMUSPE, Cesar Enrique          1.000000
# Partido_de_la_Armonía_O.D.N.         MARTINEZ IZAGUIRRE, Ruben Ariel        1.000000
# Patria_Alternativa_O.D.N.            SCIUTO OLIVERA, Ruben Javier           1.000000
# Por__Los_Cambios_Necesarios_O.D.N.   FRANCHI SORIA, Guillermo Anibal        1.000000
# Verde_Animalista_O.D.N.              RODRIGUEZ GONZALEZ, Rita Mercedes      0.786020
#                                      VIÑAS ORTIZ, Raul Eduardo              0.213980
# Name: CNT_VOTOS, dtype: float64

# %%
suma_votos_por_convocatoria.sum()
# Out:
# 883659

# %%
# @title
# 8. Primer intento de abordaje de nuestra pregunta. En los circuitos que hubo más votos al FA, sacó más votos Carolina Cosse?
# Plot de votos de Carolina Cosse vs. Votos al FA.

# Construir un nuevo dataset que sume CNT_VOTOS por PRECANDIDATO y CONVOCATORIA por cada CIRCUITO
df_sumado = df.groupby(['SERIE_CIRCUITO', 'PRECANDIDATO', 'CONVOCATORIA'])['CNT_VOTOS'].sum().reset_index()

# Filtrar para "COSSE GARRIDO, Ana Carolina" y "Frente_Amplio_-_O.D.N."
df_cosse = df_sumado[df_sumado['PRECANDIDATO'] == "COSSE GARRIDO, Ana Carolina"]
df_fa = df_sumado[df_sumado['CONVOCATORIA'] == "Frente_Amplio_-_O.D.N."].groupby('SERIE_CIRCUITO').sum().reset_index()

# Asegurarse de que cada SERIE_CIRCUITO en df_fa tenga un valor para Carolina Cosse.
# Si no tiene votos, le asignamos un valor de 0
df_cosse_filled = df_fa[['SERIE_CIRCUITO']].merge(df_cosse, on='SERIE_CIRCUITO', how='left')
df_cosse_filled['CNT_VOTOS'] = df_cosse_filled['CNT_VOTOS'].fillna(0)

# Unir los datos de Cosse y Frente Amplio
df_final = df_cosse_filled.merge(df_fa[['SERIE_CIRCUITO', 'CNT_VOTOS']], on='SERIE_CIRCUITO', suffixes=('_COSSE', '_FA'))
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_34312\2156928590.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_fa = df_sumado[df_sumado['CONVOCATORIA'] == "Frente_Amplio_-_O.D.N."].groupby('SERIE_CIRCUITO').sum().reset_index()

# %%
# @title
# Realizar el gráfico
import matplotlib.pyplot as plt

# %%
# @title
# Realizar el gráfico
plt.figure(figsize=(10, 6))
plt.scatter(df_final['CNT_VOTOS_FA'], df_final['CNT_VOTOS_COSSE'], alpha=0.1)
plt.xlabel('Suma de CNT_VOTOS para CONVOCATORIA == "Frente_Amplio_-_O.D.N."')
plt.ylabel('Suma de CNT_VOTOS para "COSSE GARRIDO, Ana Carolina"')
plt.title('Comparación de CNT_VOTOS por SERIE_CIRCUITO')
plt.show()

# %%
# @title
import numpy as np

# %%
# @title
# Extraer valores de x y y para la regresión
x = df_final['CNT_VOTOS_FA']
y = df_final['CNT_VOTOS_COSSE']

# Calcular la línea de regresión
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept

# Realizar el gráfico
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.05, label='Datos')
plt.plot(x, regression_line, color='red', label='Línea de Regresión')
plt.xlabel('Suma de CNT_VOTOS para CONVOCATORIA == "Frente_Amplio_-_O.D.N."')
plt.ylabel('Suma de CNT_VOTOS para "COSSE GARRIDO, Ana Carolina"')
plt.title('Comparación de CNT_VOTOS por SERIE_CIRCUITO')
plt.legend()
plt.show()

# %%
# @title
